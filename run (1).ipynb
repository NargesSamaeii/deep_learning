# %%
from google.colab import drive
drive.mount('/content/mydrive')
# Out:
# Mounted at /content/mydrive

# %%
# %cd /content/mydrive/MyDrive/diffiernet-master
# Out:
# /content/mydrive/.shortcut-targets-by-id/15KCrZ3p8B03AvhHz5KUSNRY8rZ6xQjbB/diffiernet-master

# %%
# !kaggle datasets download -d thtuan/btad-beantech-anomaly-detection
# Out:
# Dataset URL: https://www.kaggle.com/datasets/thtuan/btad-beantech-anomaly-detection
# License(s): unknown
# ...
#  99% 1.33G/1.34G [00:11<00:00, 104MB/s]
# 100% 1.34G/1.34G [00:11<00:00, 121MB/s]

# %%
# !unzip btad-beantech-anomaly-detection.zip
# Out:
# Archive:  btad-beantech-anomaly-detection.zip
#   inflating: BTech_Dataset_transformed/01/ground_truth/ko/0000.png
#   inflating: BTech_Dataset_transformed/01/ground_truth/ko/0001.png
#   inflating: BTech_Dataset_transformed/01/ground_truth/ko/0002.png
#   inflating: BTech_Dataset_transformed/01/ground_truth/ko/0003.png
#   inflating: BTech_Dataset_transformed/01/ground_truth/ko/0004.png
#   inflating: BTech_Dataset_transformed/01/ground_truth/ko/0005.png
#   inflating: BTech_Dataset_transformed/01/ground_truth/ko/0006.png
#   inflating: BTech_Dataset_transformed/01/ground_truth/ko/0007.png
#   inflating: BTech_Dataset_transformed/01/ground_truth/ko/0008.png
#   inflating: BTech_Dataset_transformed/01/ground_truth/ko/0009.png
#   inflating: BTech_Dataset_transformed/01/ground_truth/ko/0010.png
#   inflating: BTech_Dataset_transformed/01/ground_truth/ko/0011.png
#   inflating: BTech_Dataset_transformed/01/ground_truth/ko/0012.png
# ...

# %% [markdown]
# ## Traning

# %%
# !python main.py --dataset_path 'BTAD' --class_name '01' --model_name 'beanTech_model_cls1' --epochs 5
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
#
# Train epoch 0
# Epoch: 0.0 	 train loss: -0.0315
# Epoch: 0.1 	 train loss: -1.5898
# Epoch: 0.2 	 train loss: -1.8517
# Epoch: 0.3 	 train loss: -2.1123
# Epoch: 0.4 	 train loss: -2.1693
# Epoch: 0.5 	 train loss: -2.3147
# Epoch: 0.6 	 train loss: -2.3496
# Epoch: 0.7 	 train loss: -2.4544
#
# Compute loss and scores on test set:
# ...

# %%
# !python main.py --dataset_path 'BTAD' --class_name '02' --model_name 'beanTech_model_cls2' --epochs 5
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/alexnet-owt-7be5be79.pth" to /root/.cache/torch/hub/checkpoints/alexnet-owt-7be5be79.pth
# 100% 233M/233M [00:01<00:00, 127MB/s]
#
# Train epoch 0
# Epoch: 0.0 	 train loss: -0.3668
# Epoch: 0.1 	 train loss: -1.2836
# Epoch: 0.2 	 train loss: -1.5352
# Epoch: 0.3 	 train loss: -1.7003
# ...

# %%
# !python main.py --dataset_path 'BTAD' --class_name '03' --model_name 'beanTech_model_cls3' --epochs 5
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/alexnet-owt-7be5be79.pth" to /root/.cache/torch/hub/checkpoints/alexnet-owt-7be5be79.pth
# 100% 233M/233M [00:01<00:00, 134MB/s]
#
# Train epoch 0
# Epoch: 0.0 	 train loss: -1.5922
# Epoch: 0.1 	 train loss: 664.9653
# Epoch: 0.2 	 train loss: -2.6735
# Epoch: 0.3 	 train loss: -2.8362
# ...

# %% [markdown]
# ## Evaluation

# %%
# !python main.py --dataset_path 'BTAD/01/train/ok'  --model_name 'beanTech_model_cls1'

# %%
# !python main.py --dataset_path 'BTAD/02/train/ok'  --model_name 'beanTech_model_cls2'

# %%
# !python main.py --dataset_path 'BTAD/03/train/ok'  --model_name 'beanTech_model_cls3'
